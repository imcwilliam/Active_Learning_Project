# %%
def Run_GeoShapes_Exp(Num_Epochs):
    # %matplotlib notebook
    import keras as keras
    from keras.models import Sequential
    from keras.layers import LSTM, Dense,BatchNormalization,Dropout,Flatten, Conv1D, Conv2D,MaxPool2D
    from keras.losses import binary_crossentropy, categorical_crossentropy
    from keras.metrics import categorical_accuracy
    from keras import regularizers,optimizers
    from keras.regularizers import l2
    import numpy as np
    import scipy.io
    import matplotlib.pyplot as plt
    import gzip
    from keras.layers.core import Lambda
    from scipy.integrate import trapz
    import seaborn as sns

    from keras.layers.core import Lambda
    from keras import backend as K    
    
    def Get_Feats_and_Targets(filename):
        import numpy as np

        def line_to_Feats(line):
            line = line.split(' ')
            Feats = np.asarray(line[0:1024])
            Target = np.zeros([3])
            Target[int(line[1024])] = 1
            return Feats,Target

        f = open(filename, 'r')
        lines = f.readlines()
        Features = []
        Targets = []
        for i in range(len(lines)-1):
            line = lines[i+1]
            Feats,Tgts = line_to_Feats(line)
            Features.append(Feats)
            Targets.append(Tgts)

        return np.asarray(Features,dtype = 'float64'), np.asarray(Targets,dtype = 'int')
    
    [TrainInputs_Easy,TrainTargets_Easy] = Get_Feats_and_Targets('shapeset1_1cspo_2_3.10000.train.amat')
    [TrainInputs,TrainTargets] = Get_Feats_and_Targets('shapeset2_1cspo_2_3.10000.train.amat')
    [ValInputs,ValTargets] = Get_Feats_and_Targets('shapeset2_1cspo_2_3.5000.valid.amat')
    
    TrainInputs = np.append(TrainInputs,TrainInputs_Easy,axis=0)
    TrainTargets = np.append(TrainTargets,TrainTargets_Easy,axis=0)

    data_dim = TrainInputs.shape[1]
    NumSamples = TrainInputs.shape[0]
    Num_Targets = TrainTargets.shape[-1]


    reg_coeff = 0

    def Gen_Model(reg_coeff):
        model = Sequential()
        model.add(Dense(300,activation='tanh',input_shape =(data_dim,),kernel_regularizer=l2(reg_coeff)))
        model.add(Dropout(0.25))
        model.add(Dense(300,activation='tanh',input_shape =(data_dim,),kernel_regularizer=l2(reg_coeff)))
        model.add(Dropout(0.25))
        model.add(Dense(300,activation='tanh',input_shape =(data_dim,),kernel_regularizer=l2(reg_coeff)))
        model.add(Dropout(0.25))
        model.add(Dense(Num_Targets,activation = 'softmax',kernel_regularizer=l2(reg_coeff),input_shape =(data_dim,)))
        optim = optimizers.adam(lr=0.0001)
        model.compile(loss='categorical_crossentropy',optimizer=optim,metrics=['categorical_accuracy'])
        return model

    VarTempModel = Gen_Model(reg_coeff)
    UniTaskModel = Gen_Model(reg_coeff)
    PropTaskModel = Gen_Model(reg_coeff)
    ConstTempModel = Gen_Model(reg_coeff)
    Uni_model = Gen_Model(reg_coeff)
    
    VarTempModel.set_weights(Uni_model.get_weights())
    UniTaskModel.set_weights(Uni_model.get_weights())
    PropTaskModel.set_weights(Uni_model.get_weights())
    ConstTempModel.set_weights(Uni_model.get_weights())
    
    def acquisition_function_dist_to_threshold(model,samples,Num_Targets,temperature=1,Target_Ratio=5):
        Output = model.predict(samples)
        Output -= 1/float(Num_Targets)
        Dist_to_Threshold = np.sum(np.abs(Output),1)
        Exp_Dist_to_Threshold = np.exp(Dist_to_Threshold/temperature)
        Exp_Dist_to_Threshold *= 1
    #     Exp_Dist_to_Threshold = Dist_to_Threshold
        Sampling_Prob = Exp_Dist_to_Threshold/np.sum(Exp_Dist_to_Threshold).astype(float)
        Max_Prob_Ratio = Sampling_Prob.max()/Sampling_Prob.min()
        Target_Ratio = Target_Ratio
        if Max_Prob_Ratio < Target_Ratio:
            while Max_Prob_Ratio <Target_Ratio:
                temperature = temperature*0.99
                Exp_Dist_to_Threshold = np.exp(Dist_to_Threshold/temperature)
                StoreSampling_Prob = Sampling_Prob.copy()
                Sampling_Prob = Exp_Dist_to_Threshold/np.sum(Exp_Dist_to_Threshold).astype(float)
                Max_Prob_Ratio = Sampling_Prob.max()/Sampling_Prob.min()
                if np.isnan(Max_Prob_Ratio):
                    Sampling_Prob = StoreSampling_Prob.copy()
        else:
            while Max_Prob_Ratio > Target_Ratio:
                temperature = temperature*1.01
                Exp_Dist_to_Threshold = np.exp(Dist_to_Threshold/temperature)
                StoreSampling_Prob = Sampling_Prob.copy()
                Sampling_Prob = Exp_Dist_to_Threshold/np.sum(Exp_Dist_to_Threshold).astype(float)
                Max_Prob_Ratio = Sampling_Prob.max()/Sampling_Prob.min()
                if np.isnan(Max_Prob_Ratio):
                    Sampling_Prob = StoreSampling_Prob.copy()
        return Sampling_Prob

    def acquisition_function_dist_to_threshold_const_temp(model,samples,Num_Targets,temperature=1):
        Output = model.predict(samples)
        Output -= 1/float(Num_Targets)
        Dist_to_Threshold = np.sum(np.abs(Output),1)
        Exp_Dist_to_Threshold = np.exp(Dist_to_Threshold/temperature)
        Sampling_Prob = Exp_Dist_to_Threshold/np.sum(Exp_Dist_to_Threshold).astype(float)
        return Sampling_Prob

    count = 0 
    Num_Epochs = Num_Epochs
    Num_BurnIn = 1
    Batch_Size = 32
    
    NumTasks = 2
    try:
        SwitchPoint = np.int(Num_Epochs/NumTasks)
        print('Switch:')
        print(SwitchPoint)
    except:
        SwitchPoint = 1
    Val_Error = np.zeros([Num_Epochs,5])
    Val_Acc = np.zeros([Num_Epochs,5])

    def Biased_Batch(Inputs,Targets,Batch_Size,Sampling_Probability,Weighting_Flag = 1,NumTasks = 0,CurrentTask=0):
        while True: 
            index = np.linspace(0,Inputs.shape[0],Inputs.shape[0],endpoint=False,dtype=int)
            if NumTasks > 1:
                Cutoff = np.percentile(Sampling_Probability,np.max([100-(CurrentTask*(1/np.float(NumTasks))*100),0]))
                TaskInd = Sampling_Probability >= Cutoff
                DropInd = Sampling_Probability <  Cutoff
                Sampling_Probability[DropInd] = 0
                Sampling_Probability = Sampling_Probability/np.sum(Sampling_Probability,dtype=float)
            Batch = np.random.choice(index,size=Batch_Size,replace=False,p=Sampling_Probability)
            Batch_Inputs = Inputs[Batch,:]
            Batch_Targets = Targets[Batch,:]
            if Weighting_Flag == 1:
                FullWeights = Sampling_Probability**-1
                FullWeights = FullWeights/np.mean(FullWeights)
            elif Weighting_Flag == -1:
                FullWeights = Sampling_Probability/np.mean(Sampling_Probability)
            else:
                FullWeights = np.ones(Inputs.shape[0])
            Weights = FullWeights[Batch]
            yield (Batch_Inputs,Batch_Targets,Weights)
        
    def Biased_Batch_Uni(Inputs,Targets,Batch_Size,Sampling_Probability,Weighting_Flag = 1,NumTasks = 0,CurrentTask=0):
        while True: 
            index = np.linspace(0,Inputs.shape[0],Inputs.shape[0],endpoint=False,dtype=int)
            if NumTasks > 1:
                Cutoff = np.percentile(Sampling_Probability,np.max([100-(CurrentTask*(1/np.float(NumTasks))*100),0]))
                TaskInd = Sampling_Probability >= Cutoff
                DropInd = Sampling_Probability <  Cutoff
                Sampling_Probability[TaskInd] = 1
                Sampling_Probability[DropInd] = 0
                Sampling_Probability = Sampling_Probability/np.sum(Sampling_Probability,dtype=float)
            Batch = np.random.choice(index,size=Batch_Size,replace=False,p=Sampling_Probability)
            Batch_Inputs = Inputs[Batch,:]
            Batch_Targets = Targets[Batch,:]
            if Weighting_Flag == 1:
                FullWeights = Sampling_Probability**-1
                FullWeights = FullWeights/np.mean(FullWeights)
            elif Weighting_Flag == -1:
                FullWeights = Sampling_Probability/np.mean(Sampling_Probability)
            else:
                FullWeights = np.ones(Inputs.shape[0])
            Weights = FullWeights[Batch]
            yield (Batch_Inputs,Batch_Targets,Weights)
            
    fig = plt.figure(figsize = [4,4])
    ax = fig.add_subplot(111)
    plt.ion()
    fig.show()
    fig.canvas.draw()

    fig2 = plt.figure(figsize = [4,4])
    ax2 = fig2.add_subplot(111)
    plt.ion()
    fig2.show()
    fig2.canvas.draw()


    for EpochLoop in  range(Num_Epochs):
        if count < Num_BurnIn:
            Uni_model.fit(TrainInputs,TrainTargets,batch_size = Batch_Size,epochs=1,verbose=1)
            Error = Uni_model.test_on_batch(ValInputs,ValTargets)
            Val_Error[count,:] = Error[0]
            Val_Acc[count,:] = Error[1]
            
            VarTempModel.set_weights(Uni_model.get_weights())
            UniTaskModel.set_weights(Uni_model.get_weights())
            PropTaskModel.set_weights(Uni_model.get_weights())
            ConstTempModel.set_weights(Uni_model.get_weights())
        else:
            
            VarTempModel_Probability = 1/acquisition_function_dist_to_threshold(VarTempModel,TrainInputs,Num_Targets,1,10)
            VarTempModel_Probability/= VarTempModel_Probability.sum().astype(float)
            
            UniTaskModel_Probability = 1/acquisition_function_dist_to_threshold_const_temp(UniTaskModel,TrainInputs,Num_Targets,1)
            UniTaskModel_Probability/= UniTaskModel_Probability.sum().astype(float)
            
            PropTaskModel_Probability = 1/acquisition_function_dist_to_threshold(PropTaskModel,TrainInputs,Num_Targets,1,10)
            PropTaskModel_Probability/= PropTaskModel_Probability.sum().astype(float)
            
            ConstTempModel_Probability = 1/acquisition_function_dist_to_threshold_const_temp(ConstTempModel,TrainInputs,Num_Targets,0.5)
            ConstTempModel_Probability/= ConstTempModel_Probability.sum().astype(float)
            
            print(np.max(ConstTempModel_Probability)/np.min(ConstTempModel_Probability))
            
            VarTempModel.fit_generator(Biased_Batch(TrainInputs,TrainTargets,Batch_Size,VarTempModel_Probability,0,0,np.int((count-Num_BurnIn)/SwitchPoint)+1),
                                       steps_per_epoch=np.int(NumSamples/Batch_Size),verbose=0)
            
            Phase = np.int((count-Num_BurnIn)/SwitchPoint)+1
            
            PhaseScale = np.int(NumTasks/Phase)
            
            UniTaskModel.fit_generator(Biased_Batch_Uni(TrainInputs,TrainTargets,Batch_Size,UniTaskModel_Probability,0,NumTasks,np.int((count-Num_BurnIn)/SwitchPoint)+1),  
                                       steps_per_epoch=np.int(PhaseScale*(NumSamples/Batch_Size)),verbose=0)
            
            PropTaskModel.fit_generator(Biased_Batch(TrainInputs,TrainTargets,Batch_Size,PropTaskModel_Probability,0,NumTasks,np.int((count-Num_BurnIn)/SwitchPoint)+1),
                                       steps_per_epoch=np.int(PhaseScale*(NumSamples/Batch_Size)),verbose=0)
            
            ConstTempModel.fit_generator(Biased_Batch(TrainInputs,TrainTargets,Batch_Size,ConstTempModel_Probability,0,0,np.int((count-Num_BurnIn)/SwitchPoint)+1),
                                       steps_per_epoch=np.int(NumSamples/Batch_Size),verbose=0)

            Uni_model.fit_generator(Biased_Batch(TrainInputs,TrainTargets,Batch_Size,1/np.float(NumSamples)*np.ones(NumSamples),0),
                                    steps_per_epoch=np.int(NumSamples/Batch_Size),verbose=1)

            Error = VarTempModel.test_on_batch(ValInputs,ValTargets)
            Val_Error[count,0] = Error[0]
            Val_Acc[count,0] = Error[1]

            Error = UniTaskModel.test_on_batch(ValInputs,ValTargets)
            Val_Error[count,1] = Error[0]
            Val_Acc[count,1] = Error[1]
            
            Error = PropTaskModel.test_on_batch(ValInputs,ValTargets)
            Val_Error[count,2] = Error[0]
            Val_Acc[count,2] = Error[1]
            
            Error = ConstTempModel.test_on_batch(ValInputs,ValTargets)
            Val_Error[count,3] = Error[0]
            Val_Acc[count,3] = Error[1]

            Error = Uni_model.test_on_batch(ValInputs,ValTargets)
            Val_Error[count,4] = Error[0]
            Val_Acc[count,4] = Error[1]
            
            print(EpochLoop)

        count += 1
        
        ax.clear()
        ax.plot(Val_Error[0:count,0],label='VarTemp')
        ax.plot(Val_Error[0:count,1],label='UniTask')
        ax.plot(Val_Error[0:count,2],label='PropTask')
        ax.plot(Val_Error[0:count,3],label='ConstTemp')
        ax.plot(Val_Error[0:count,4],label='Uniform')
        ax.legend(loc='best')
        fig.canvas.draw()

        ax2.clear()
        ax2.plot(Val_Acc[0:count,0],label='High D2T')
        ax2.plot(Val_Acc[0:count,1],label='UniTask')
        ax2.plot(Val_Acc[0:count,2],label='PropTask')
        ax2.plot(Val_Acc[0:count,3],label='ConstTemp')
        ax2.plot(Val_Acc[0:count,4],label='Uniform')
        fig2.canvas.draw()

    [TestInputs,TestTargets] = Get_Feats_and_Targets('shapeset2_1cspo_2_3.5000.test.amat')

    TestError = np.zeros([5,2])
    TestError[0,:] = VarTempModel.test_on_batch(TestInputs,TestTargets)
    TestError[1,:] = UniTaskModel.test_on_batch(TestInputs,TestTargets)
    TestError[2,:] = PropTaskModel.test_on_batch(TestInputs,TestTargets)
    TestError[3,:] = ConstTempModel.test_on_batch(TestInputs,TestTargets)
    TestError[4,:] = Uni_model.test_on_batch(TestInputs,TestTargets)
    
    

    return TestError, Val_Error,Val_Acc

# %%
import numpy as np
import datetime
NumRuns = 100
NumEpochs = 350

TestError = np.zeros([5,2,NumRuns])
Val_Error = np.zeros([NumEpochs,5,NumRuns])
Val_Acc = np.zeros([NumEpochs,5,NumRuns])

# %%
from IPython.display import clear_output
for i in range(NumRuns):
    clear_output()
    print(i)
    TestError[:,:,i],Val_Error[:,:,i],Val_Acc[:,:,i] = Run_GeoShapes_Exp(NumEpochs)
    np.save("Test_Performance_Geo_Various_Hard",TestError)
    np.save("Val_Error_Geo_Various_Hard",Val_Error)
    np.save("Val_Acc_Geo_Various_Hard",Val_Acc)
# Out:
# 8
# Switch:
# 175
# <img src="data:image/png;base64,..." width="400">
# <img src="data:image/png;base64,..." width="400">
# Epoch 1/1
# 20000/20000 [==============================] - 8s 415us/step - loss: 1.1704 - categorical_accuracy: 0.3469
# 2.3420043
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 1.1514 - categorical_accuracy: 0.3479
# 1
# 2.8401957
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 1.1322 - categorical_accuracy: 0.3616
# 2
# 4.5741806
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 1.1274 - categorical_accuracy: 0.3599
# 3
# 2.5295167
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 1.1225 - categorical_accuracy: 0.3637
# 4
# 4.389699
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 1.1126 - categorical_accuracy: 0.3750
# 5
# 4.7218385
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 1.1050 - categorical_accuracy: 0.3831
# 6
# 4.1277785
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 1.0956 - categorical_accuracy: 0.4001
# 7
# 4.9071517
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 1.0790 - categorical_accuracy: 0.4130
# 8
# 5.6932154
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 1.0717 - categorical_accuracy: 0.4279
# 9
# 7.225417
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 1.0555 - categorical_accuracy: 0.4435
# 10
# 7.545095
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 1.0502 - categorical_accuracy: 0.4547
# 11
# 7.810122
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 1.0407 - categorical_accuracy: 0.4678
# 12
# 7.5172353
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 1.0284 - categorical_accuracy: 0.4764
# 13
# 7.2668033
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 1.0173 - categorical_accuracy: 0.4921
# 14
# 7.1909547
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 1.0059 - categorical_accuracy: 0.5060
# 15
# 7.807557
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.9901 - categorical_accuracy: 0.5249
# 16
# 9.033513
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.9792 - categorical_accuracy: 0.5282
# 17
# 7.673866
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.9749 - categorical_accuracy: 0.5291
# 18
# 9.085049
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.9634 - categorical_accuracy: 0.5441
# 19
# 8.505747
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.9554 - categorical_accuracy: 0.5501
# 20
# 8.294842
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.9434 - categorical_accuracy: 0.5568
# 21
# 8.555699
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.9335 - categorical_accuracy: 0.5620
# 22
# 8.440364
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.9264 - categorical_accuracy: 0.5638
# 23
# 8.976625
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.9092 - categorical_accuracy: 0.5759
# 24
# 9.4649515
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.9118 - categorical_accuracy: 0.5740
# 25
# 8.864393
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.8977 - categorical_accuracy: 0.5892
# 26
# 8.713338
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.8855 - categorical_accuracy: 0.5947
# 27
# 8.716941
# Epoch 1/1
# 625/625 [==============================] - 5s 8ms/step - loss: 0.8869 - categorical_accuracy: 0.5876
# 28
# 8.798326
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.8745 - categorical_accuracy: 0.5986
# 29
# 9.68365
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.8694 - categorical_accuracy: 0.6050
# 30
# 9.82023
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.8654 - categorical_accuracy: 0.6033
# 31
# 10.144771
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.8530 - categorical_accuracy: 0.6096
# 32
# 10.230291
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.8434 - categorical_accuracy: 0.6182
# 33
# 9.85281
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.8381 - categorical_accuracy: 0.6201
# 34
# 9.983591
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.8267 - categorical_accuracy: 0.6269
# 35
# 10.703409
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.8352 - categorical_accuracy: 0.6219
# 36
# 11.089168
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.8151 - categorical_accuracy: 0.6316
# 37
# 10.206382
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.8179 - categorical_accuracy: 0.6310
# 38
# 11.192838
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.8125 - categorical_accuracy: 0.6361
# 39
# 10.496492
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.8081 - categorical_accuracy: 0.6390
# 40
# 11.261462
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.7918 - categorical_accuracy: 0.6485
# 41
# 11.421786
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.7973 - categorical_accuracy: 0.6424
# 42
# 11.726354
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.7847 - categorical_accuracy: 0.6494
# 43
# 11.201464
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.7784 - categorical_accuracy: 0.6517
# 44
# 12.084227
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.7748 - categorical_accuracy: 0.6546
# 45
# 11.954119
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.7678 - categorical_accuracy: 0.6573
# 46
# 11.285418
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.7573 - categorical_accuracy: 0.6637
# 47
# 11.323082
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.7503 - categorical_accuracy: 0.6681
# 48
# 11.448892
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.7551 - categorical_accuracy: 0.6653
# 49
# 12.104306
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.7543 - categorical_accuracy: 0.6649
# 50
# 11.71653
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0.7470 - categorical_accuracy: 0.6661
# 51
# 11.978925
# Epoch 1/1
# 625/625 [==============================] - 5s 9ms/step - loss: 0
# 625/625 [==============================] - 6s 9ms/step - loss: 0.3302 - categorical_accuracy: 0.8661
# 247
# 13.09929

# %%
Val_Error.shape
# Out:
# (1, 3)

# %%
5/3
# Out:
# 1.6666666666666667

# %%
np.max([-33,0])
# Out:
# 0

# %%
# %matplotlib notebook
import keras as keras
from keras.models import Sequential
from keras.layers import LSTM, Dense,BatchNormalization,Dropout,Flatten, Conv1D, Conv2D,MaxPool2D
from keras.losses import binary_crossentropy, categorical_crossentropy
from keras.metrics import categorical_accuracy
from keras import regularizers,optimizers
from keras.regularizers import l2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
import gzip
from keras.layers.core import Lambda
from scipy.integrate import trapz
import seaborn as sns

from keras.layers.core import Lambda
from keras import backend as K    

def Get_Feats_and_Targets(filename):
    import numpy as np

    def line_to_Feats(line):
        line = line.split(' ')
        Feats = np.asarray(line[0:1024])
        Target = np.zeros([3])
        Target[int(line[1024])] = 1
        return Feats,Target

    f = open(filename, 'r')
    lines = f.readlines()
    Features = []
    Targets = []
    for i in range(len(lines)-1):
        line = lines[i+1]
        Feats,Tgts = line_to_Feats(line)
        Features.append(Feats)
        Targets.append(Tgts)

    return np.asarray(Features,dtype = 'float64'), np.asarray(Targets,dtype = 'int')

[TrainInputs_Easy,TrainTargets_Easy] = Get_Feats_and_Targets('shapeset1_1cspo_2_3.10000.train.amat')
[TrainInputs,TrainTargets] = Get_Feats_and_Targets('shapeset2_1cspo_2_3.10000.train.amat')
[ValInputs,ValTargets] = Get_Feats_and_Targets('shapeset2_1cspo_2_3.5000.valid.amat')

TrainInputs = np.append(TrainInputs,TrainInputs_Easy,axis=0)
TrainTargets = np.append(TrainTargets,TrainTargets_Easy,axis=0)

data_dim = TrainInputs.shape[1]
NumSamples = TrainInputs.shape[0]
Num_Targets = TrainTargets.shape[-1]


reg_coeff = 0

def Gen_Model(reg_coeff):
    model = Sequential()
    model.add(Dense(300,activation='tanh',input_shape =(data_dim,),kernel_regularizer=l2(reg_coeff)))
    model.add(Dropout(0.25))
    model.add(Dense(300,activation='tanh',input_shape =(data_dim,),kernel_regularizer=l2(reg_coeff)))
    model.add(Dropout(0.25))
    model.add(Dense(300,activation='tanh',input_shape =(data_dim,),kernel_regularizer=l2(reg_coeff)))
    model.add(Dropout(0.25))
    model.add(Dense(Num_Targets,activation = 'softmax',kernel_regularizer=l2(reg_coeff),input_shape =(data_dim,)))
    optim = optimizers.adam(lr=0.0001)
    model.compile(loss='categorical_crossentropy',optimizer=optim,metrics=['categorical_accuracy'])
    return model

VarTempModel = Gen_Model(reg_coeff)
UniTaskModel = Gen_Model(reg_coeff)
PropTaskModel = Gen_Model(reg_coeff)
ConstTempModel = Gen_Model(reg_coeff)
Uni_model = Gen_Model(reg_coeff)

VarTempModel.set_weights(Uni_model.get_weights())
UniTaskModel.set_weights(Uni_model.get_weights())
PropTaskModel.set_weights(Uni_model.get_weights())
ConstTempModel.set_weights(Uni_model.get_weights())

def acquisition_function_dist_to_threshold(model,samples,Num_Targets,temperature=1,Target_Ratio=5):
    Output = model.predict(samples)
    Output -= 1/float(Num_Targets)
    Dist_to_Threshold = np.sum(np.abs(Output),1)
    Exp_Dist_to_Threshold = np.exp(Dist_to_Threshold/temperature)
    Exp_Dist_to_Threshold *= 1
#     Exp_Dist_to_Threshold = Dist_to_Threshold
    Sampling_Prob = Exp_Dist_to_Threshold/np.sum(Exp_Dist_to_Threshold).astype(float)
    Max_Prob_Ratio = Sampling_Prob.max()/Sampling_Prob.min()
    Target_Ratio = Target_Ratio
    if Max_Prob_Ratio < Target_Ratio:
        while Max_Prob_Ratio <Target_Ratio:
            temperature = temperature*0.99
            Exp_Dist_to_Threshold = np.exp(Dist_to_Threshold/temperature)
            StoreSampling_Prob = Sampling_Prob.copy()
            Sampling_Prob = Exp_Dist_to_Threshold/np.sum(Exp_Dist_to_Threshold).astype(float)
            Max_Prob_Ratio = Sampling_Prob.max()/Sampling_Prob.min()
            if np.isnan(Max_Prob_Ratio):
                Sampling_Prob = StoreSampling_Prob.copy()
    else:
        while Max_Prob_Ratio > Target_Ratio:
            temperature = temperature*1.01
            Exp_Dist_to_Threshold = np.exp(Dist_to_Threshold/temperature)
            StoreSampling_Prob = Sampling_Prob.copy()
            Sampling_Prob = Exp_Dist_to_Threshold/np.sum(Exp_Dist_to_Threshold).astype(float)
            Max_Prob_Ratio = Sampling_Prob.max()/Sampling_Prob.min()
            if np.isnan(Max_Prob_Ratio):
                Sampling_Prob = StoreSampling_Prob.copy()
    return Sampling_Prob

def acquisition_function_dist_to_threshold_const_temp(model,samples,Num_Targets,temperature=1):
    Output = model.predict(samples)
    Output -= 1/float(Num_Targets)
    Dist_to_Threshold = np.sum(np.abs(Output),1)
    Exp_Dist_to_Threshold = np.exp(Dist_to_Threshold/temperature)
    Sampling_Prob = Exp_Dist_to_Threshold/np.sum(Exp_Dist_to_Threshold).astype(float)
    return Sampling_Prob

count = 0 
Num_Epochs = 350
Num_BurnIn = 1
Batch_Size = 32

NumTasks = 2
try:
    SwitchPoint = np.int(Num_Epochs/NumTasks)
    print('Switch:')
    print(SwitchPoint)
except:
    SwitchPoint = 1
Val_Error = np.zeros([Num_Epochs,5])
Val_Acc = np.zeros([Num_Epochs,5])

def Biased_Batch(Inputs,Targets,Batch_Size,Sampling_Probability,Weighting_Flag = 1,NumTasks = 0,CurrentTask=0):
    while True: 
        index = np.linspace(0,Inputs.shape[0],Inputs.shape[0],endpoint=False,dtype=int)
        if NumTasks > 1:
            Cutoff = np.percentile(Sampling_Probability,np.max([100-(CurrentTask*(1/np.float(NumTasks))*100),0]))
            TaskInd = Sampling_Probability >= Cutoff
            DropInd = Sampling_Probability <  Cutoff
            Sampling_Probability[DropInd] = 0
            Sampling_Probability = Sampling_Probability/np.sum(Sampling_Probability,dtype=float)
        Batch = np.random.choice(index,size=Batch_Size,replace=False,p=Sampling_Probability)
        Batch_Inputs = Inputs[Batch,:]
        Batch_Targets = Targets[Batch,:]
        if Weighting_Flag == 1:
            FullWeights = Sampling_Probability**-1
            FullWeights = FullWeights/np.mean(FullWeights)
        elif Weighting_Flag == -1:
            FullWeights = Sampling_Probability/np.mean(Sampling_Probability)
        else:
            FullWeights = np.ones(Inputs.shape[0])
        Weights = FullWeights[Batch]
        yield (Batch_Inputs,Batch_Targets,Weights)

def Biased_Batch_Uni(Inputs,Targets,Batch_Size,Sampling_Probability,Weighting_Flag = 1,NumTasks = 0,CurrentTask=0):
    while True: 
        index = np.linspace(0,Inputs.shape[0],Inputs.shape[0],endpoint=False,dtype=int)
        if NumTasks > 1:
            Cutoff = np.percentile(Sampling_Probability,np.max([100-(CurrentTask*(1/np.float(NumTasks))*100),0]))
            TaskInd = Sampling_Probability >= Cutoff
            DropInd = Sampling_Probability <  Cutoff
            Sampling_Probability[TaskInd] = 1
            Sampling_Probability[DropInd] = 0
            Sampling_Probability = Sampling_Probability/np.sum(Sampling_Probability,dtype=float)
        Batch = np.random.choice(index,size=Batch_Size,replace=False,p=Sampling_Probability)
        Batch_Inputs = Inputs[Batch,:]
        Batch_Targets = Targets[Batch,:]
        if Weighting_Flag == 1:
            FullWeights = Sampling_Probability**-1
            FullWeights = FullWeights/np.mean(FullWeights)
        elif Weighting_Flag == -1:
            FullWeights = Sampling_Probability/np.mean(Sampling_Probability)
        else:
            FullWeights = np.ones(Inputs.shape[0])
        Weights = FullWeights[Batch]
        yield (Batch_Inputs,Batch_Targets,Weights)

fig = plt.figure(figsize = [4,4])
ax = fig.add_subplot(111)
plt.ion()
fig.show()
fig.canvas.draw()

fig2 = plt.figure(figsize = [4,4])
ax2 = fig2.add_subplot(111)
plt.ion()
fig2.show()
fig2.canvas.draw()


for EpochLoop in  range(Num_Epochs):
    if count < Num_BurnIn:
        Uni_model.fit(TrainInputs,TrainTargets,batch_size = Batch_Size,epochs=1,verbose=1)
        Error = Uni_model.test_on_batch(ValInputs,ValTargets)
        Val_Error[count,:] = Error[0]
        Val_Acc[count,:] = Error[1]

        VarTempModel.set_weights(Uni_model.get_weights())
        UniTaskModel.set_weights(Uni_model.get_weights())
        PropTaskModel.set_weights(Uni_model.get_weights())
        ConstTempModel.set_weights(Uni_model.get_weights())
    else:

        VarTempModel_Probability = acquisition_function_dist_to_threshold(VarTempModel,TrainInputs,Num_Targets,1,10)
        VarTempModel_Probability/= VarTempModel_Probability.sum().astype(float)

        UniTaskModel_Probability = acquisition_function_dist_to_threshold_const_temp(UniTaskModel,TrainInputs,Num_Targets,1)
        UniTaskModel_Probability/= UniTaskModel_Probability.sum().astype(float)

        PropTaskModel_Probability = acquisition_function_dist_to_threshold(PropTaskModel,TrainInputs,Num_Targets,1,10)
        PropTaskModel_Probability/= PropTaskModel_Probability.sum().astype(float)

        ConstTempModel_Probability = acquisition_function_dist_to_threshold_const_temp(ConstTempModel,TrainInputs,Num_Targets,0.5)
        ConstTempModel_Probability/= ConstTempModel_Probability.sum().astype(float)

        print(np.max(ConstTempModel_Probability)/np.min(ConstTempModel_Probability))

        VarTempModel.fit_generator(Biased_Batch(TrainInputs,TrainTargets,Batch_Size,VarTempModel_Probability,0,0,np.int((count-Num_BurnIn)/SwitchPoint)+1),
                                   steps_per_epoch=np.int(NumSamples/Batch_Size),verbose=0)
    
        
        Phase = np.int((count-Num_BurnIn)/SwitchPoint)+1
        PhaseEpochs = np.int(NumTasks/Phase)

        UniTaskModel.fit_generator(Biased_Batch_Uni(TrainInputs,TrainTargets,Batch_Size,UniTaskModel_Probability,0,NumTasks,np.int((count-Num_BurnIn)/SwitchPoint)+1),  
                                   steps_per_epoch=np.int(PhaseEpochs*(NumSamples/Batch_Size)),verbose=1)

        PropTaskModel.fit_generator(Biased_Batch(TrainInputs,TrainTargets,Batch_Size,PropTaskModel_Probability,0,NumTasks,np.int((count-Num_BurnIn)/SwitchPoint)+1),
                                   steps_per_epoch=np.int(PhaseEpochs*(NumSamples/Batch_Size)),verbose=1)

        ConstTempModel.fit_generator(Biased_Batch(TrainInputs,TrainTargets,Batch_Size,ConstTempModel_Probability,0,0,np.int((count-Num_BurnIn)/SwitchPoint)+1),
                                   steps_per_epoch=np.int(NumSamples/Batch_Size),verbose=0)

        Uni_model.fit_generator(Biased_Batch(TrainInputs,TrainTargets,Batch_Size,1/np.float(NumSamples)*np.ones(NumSamples),0),
                                steps_per_epoch=np.int(NumSamples/Batch_Size),verbose=1)

        Error = VarTempModel.test_on_batch(ValInputs,ValTargets)
        Val_Error[count,0] = Error[0]
        Val_Acc[count,0] = Error[1]

        Error = UniTaskModel.test_on_batch(ValInputs,ValTargets)
        Val_Error[count,1] = Error[0]
        Val_Acc[count,1] = Error[1]

        Error = PropTaskModel.test_on_batch(ValInputs,ValTargets)
        Val_Error[count,2] = Error[0]
        Val_Acc[count,2] = Error[1]

        Error = ConstTempModel.test_on_batch(ValInputs,ValTargets)
        Val_Error[count,3] = Error[0]
        Val_Acc[count,3] = Error[1]

        Error = Uni_model.test_on_batch(ValInputs,ValTargets)
        Val_Error[count,4] = Error[0]
        Val_Acc[count,4] = Error[1]

        print(EpochLoop)

    count += 1

    ax.clear()
    ax.plot(Val_Error[0:count,0],label='VarTemp')
    ax.plot(Val_Error[0:count,1],label='UniTask')
    ax.plot(Val_Error[0:count,2],label='PropTask')
    ax.plot(Val_Error[0:count,3],label='ConstTemp')
    ax.plot(Val_Error[0:count,4],label='Uniform')
    ax.legend(loc='best')
    fig.canvas.draw()

    ax2.clear()
    ax2.plot(Val_Acc[0:count,0],label='High D2T')
    ax2.plot(Val_Acc[0:count,1],label='UniTask')
    ax2.plot(Val_Acc[0:count,2],label='PropTask')
    ax2.plot(Val_Acc[0:count,3],label='ConstTemp')
    ax2.plot(Val_Acc[0:count,4],label='Uniform')
    fig2.canvas.draw()

[TestInputs,TestTargets] = Get_Feats_and_Targets('shapeset2_1cspo_2_3.5000.test.amat')

TestError = np.zeros([5,2])
TestError[0,:] = VarTempModel.test_on_batch(TestInputs,TestTargets)
TestError[1,:] = UniTaskModel.test_on_batch(TestInputs,TestTargets)
TestError[2,:] = PropTaskModel.test_on_batch(TestInputs,TestTargets)
TestError[3,:] = ConstTempModel.test_on_batch(TestInputs,TestTargets)
TestError[4,:] = Uni_model.test_on_batch(TestInputs,TestTargets)
# Out:
# Switch:
# 175
# <img src="data:image/png;base64,..." width="400">
# <img src="data:image/png;base64,..." width="400">
# Epoch 1/1
# 20000/20000 [==============================] - 5s 268us/step - loss: 1.1699 - categorical_accuracy: 0.3407
# 2.743253
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.1217 - categorical_accuracy: 0.3846
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.1069 - categorical_accuracy: 0.4022
# Epoch 1/1
# 625/625 [==============================] - 5s 8ms/step - loss: 1.1420 - categorical_accuracy: 0.3544
# 1
# 2.5743234
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.0876 - categorical_accuracy: 0.4148
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.0257 - categorical_accuracy: 0.4760
# Epoch 1/1
# 625/625 [==============================] - 5s 8ms/step - loss: 1.1309 - categorical_accuracy: 0.3662
# 2
# 5.5147266
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.0357 - categorical_accuracy: 0.4734
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.9885 - categorical_accuracy: 0.5096
# Epoch 1/1
# 625/625 [==============================] - 5s 8ms/step - loss: 1.1203 - categorical_accuracy: 0.3660
# 3
# 4.9048
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.0371 - categorical_accuracy: 0.4627
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.8931 - categorical_accuracy: 0.5905
# Epoch 1/1
# 625/625 [==============================] - 5s 8ms/step - loss: 1.1163 - categorical_accuracy: 0.3730
# 4
# 9.539154
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.9706 - categorical_accuracy: 0.5332
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.8551 - categorical_accuracy: 0.6187
# Epoch 1/1
# 625/625 [==============================] - 5s 8ms/step - loss: 1.1108 - categorical_accuracy: 0.3795
# 5
# 10.093272
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.9141 - categorical_accuracy: 0.5914
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.7760 - categorical_accuracy: 0.6713
# Epoch 1/1
# 625/625 [==============================] - 5s 8ms/step - loss: 1.0994 - categorical_accuracy: 0.3921
# 6
# 10.156465
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.8437 - categorical_accuracy: 0.6438
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.6980 - categorical_accuracy: 0.7198
# Epoch 1/1
# 625/625 [==============================] - 5s 8ms/step - loss: 1.0916 - categorical_accuracy: 0.3995
# 7
# 11.319821
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.8190 - categorical_accuracy: 0.6493
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.6855 - categorical_accuracy: 0.7183
# Epoch 1/1
# 625/625 [==============================] - 5s 8ms/step - loss: 1.0857 - categorical_accuracy: 0.4037
# 8
# 11.250932
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.7613 - categorical_accuracy: 0.6859
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.6559 - categorical_accuracy: 0.7335
# Epoch 1/1
# 625/625 [==============================] - 5s 8ms/step - loss: 1.0721 - categorical_accuracy: 0.4253
# 9
# 12.160674
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.6978 - categorical_accuracy: 0.7218
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5849 - categorical_accuracy: 0.7732
# Epoch 1/1
# 625/625 [==============================] - 5s 8ms/step - loss: 1.0569 - categorical_accuracy: 0.4427
# 10
# 12.013206
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.6669 - categorical_accuracy: 0.7395
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5485 - categorical_accuracy: 0.7940
# Epoch 1/1
# 625/625 [==============================] - 5s 8ms/step - loss: 1.0513 - categorical_accuracy: 0.4543
# 11
# 12.212175
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.6795 - categorical_accuracy: 0.7209
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5502 - categorical_accuracy: 0.7836
# Epoch 1/1
# 625/625 [==============================] - 5s 8ms/step - loss: 1.0392 - categorical_accuracy: 0.4679
# 12
# 11.94878
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.6238 - categorical_accuracy: 0.7536
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5596 - categorical_accuracy: 0.7725
# Epoch 1/1
# 625/625 [==============================] - 5s 8ms/step - loss: 1.0253 - categorical_accuracy: 0.4818
# 13
# 12.791226
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.6000 - categorical_accuracy: 0.7682
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.4780 - categorical_accuracy: 0.8201
# Epoch 1/1
# 625/625 [==============================] - 5s 8ms/step - loss: 1.0124 - categorical_accuracy: 0.4948
# 14
# 13.011208
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5739 - categorical_accuracy: 0.7734
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.4672 - categorical_accuracy: 0.8246
# Epoch 1/1
# 625/625 [==============================] - 5s 8ms/step - loss: 1.0039 - categorical_accuracy: 0.5066
# 15
# 12.746711
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5742 - categorical_accuracy: 0.7735
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.4600 - categorical_accuracy: 0.8273
# Epoch 1/1
# 625/625 [==============================] - 5s 8ms/step - loss: 0.9948 - categorical_accuracy: 0.5156
# 16
# 12.66522
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5210 - categorical_accuracy: 0.8015
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.4336 - categorical_accuracy: 0.8368
# Epoch 1/1
# 625/625 [==============================] - 5s 8ms/step - loss: 0.9811 - categorical_accuracy: 0.5220
# 17
# 12.912172
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5262 - categorical_accuracy: 0.7952
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.4191 - categorical_accuracy: 0.8457
# Epoch 1/1
# 625/625 [==============================] - 5s 8ms/step - loss: 0.9667 - categorical_accuracy: 0.5342
# 18
# 13.209317
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.4934 - categorical_accuracy: 0.8129
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.3731 - categorical_accuracy: 0.8679
# Epoch 1/1
# 625/625 [==============================] - 5s 8ms/step - loss: 0.9630 - categorical_accuracy: 0.5404
# 19
# 13.182004
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.4755 - categorical_accuracy: 0.8226
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.3788 - categorical_accuracy: 0.8621
# Epoch 1/1
# 625/625 [==============================] - 5s 8ms/step - loss: 0.9514 - categorical_accuracy: 0.5494
# 20
# 13.277004
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.4423 - categorical_accuracy: 0.8368
# Epoch 1/1
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.3466 - categorical_accuracy: 0.8773
# Epoch 1/1
# 463/625 [=====================>........] - ETA: 1s - loss: 0.9365 - categorical_accuracy: 0.5637
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-ce8a8b1ea087> in <module>()
#     233
#     234         Uni_model.fit_generator(Biased_Batch(TrainInputs,TrainTargets,Batch_Size,1/np.float(NumSamples)*np.ones(NumSamples),0),
# --> 235                                 steps_per_epoch=np.int(NumSamples/Batch_Size),verbose=1)
#     236
#     237         Error = VarTempModel.test_on_batch(ValInputs,ValTargets)
#
# C:\Users\ian mcwilliam\AppData\Local\Continuum\Anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# C:\Users\ian mcwilliam\AppData\Local\Continuum\Anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1424             use_multiprocessing=use_multiprocessing,
#    1425             shuffle=shuffle,
# -> 1426             initial_epoch=initial_epoch)
#    1427
#    1428     @interfaces.legacy_generator_methods_support
#
# C:\Users\ian mcwilliam\AppData\Local\Continuum\Anaconda3\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     189                 outs = model.train_on_batch(x, y,
#     190                                             sample_weight=sample_weight,
# --> 191                                             class_weight=class_weight)
#     192
#     193                 if not isinstance(outs, list):
#
# C:\Users\ian mcwilliam\AppData\Local\Continuum\Anaconda3\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1218             ins = x + y + sample_weights
#    1219         self._make_train_function()
# -> 1220         outputs = self.train_function(ins)
#    1221         if len(outputs) == 1:
#    1222             return outputs[0]
#
# C:\Users\ian mcwilliam\AppData\Local\Continuum\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2659                 return self._legacy_call(inputs)
#    2660
# -> 2661             return self._call(inputs)
#    2662         else:
#    2663             if py_any(is_tensor(x) for x in inputs):
#
# C:\Users\ian mcwilliam\AppData\Local\Continuum\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2629                                 symbol_vals,
#    2630                                 session)
# -> 2631         fetched = self._callable_fn(*array_vals)
#    2632         return fetched[:len(self.outputs)]
#    2633
#
# C:\Users\ian mcwilliam\AppData\Local\Continuum\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args)
#    1449         if self._session._created_with_new_api:
#    1450           return tf_session.TF_SessionRunCallable(
# -> 1451               self._session._session, self._handle, args, status, None)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
#
# KeyboardInterrupt:

# %%
TaskSize
# Out:
# 10000.0

# %%
Phase = np.int((count-Num_BurnIn)/SwitchPoint)+1

# %%
np.int(NumTasks/Phase)
# Out:
# 2

# %%
NumSamples/Batch_Size
# Out:
# 625.0
