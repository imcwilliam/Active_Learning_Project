# %%
import numpy as np
TestPerf = np.load("Test_Perf_Record_CurriculumBaseline.npy")
ValError = np.load("Val_Error_Record_CurriculumBaseline.npy")

# %%
this = np.sum(np.sum(TestPerf,axis=0),axis=0)

FinalInd = 0
while this[FinalInd] >0:
    FinalInd +=1
print(FinalInd)
# Out:
# 31

# %%
NumComplete = FinalInd
TestPerf = TestPerf[:,:,0:NumComplete]
ValError = ValError[:,:,0:NumComplete]

# %%
TestPerf_Mean = TestPerf.mean(axis=2)
TestPerf_StE = TestPerf.std(axis=2) / np.sqrt(NumComplete)

# %%
import matplotlib.pyplot as plt

flag = 1

labels = ['Hard','Easy','Uni','Curriculum']
plt.errorbar(np.array([1,2,3,4],dtype=int),TestPerf_Mean[:,flag],yerr = TestPerf_StE[:,flag],marker ='x',linestyle='none')
my_xticks = ['UniHard','UniEasy','Uniform','Curriculum']
plt.xticks(np.array([1,2,3,4],dtype=int), my_xticks)
thisplot = plt.gca()
thisplot.set_xlim(0,5)

plt.show()

# %%
plt.plot(np.mean(ValError,axis=2))
plt.legend(['UniHard','UniEasy','Uniform','Curriculum'])

# %%
plt.show()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
data = TestPerf[:,0,:]
ax.boxplot(data.T)
my_xticks = ['UniHard','UniEasy','Uniform','Curriculum']
plt.xticks(np.array([1,2,3,4],dtype=int), my_xticks)
plt.show()

# %%
this= TestPerf
print(this)
# Out:
# [[[1.64788914 1.57040477 1.4617362  1.52032113 1.46300006]
#   [0.57059997 0.60500002 0.61019999 0.59680003 0.60759997]]
#
#  [[1.22482848 1.20158541 1.16731894 1.18580973 1.35546362]
#   [0.60460001 0.61180001 0.62120003 0.616      0.56919998]]
#
#  [[1.46504843 1.28539801 1.27176762 1.3592912  1.26057982]
#   [0.58880001 0.62099999 0.62559998 0.60479999 0.62760001]]
#
#  [[0.96598488 0.90742564 0.94680679 0.98240221 0.96013111]
#   [0.63739997 0.65319997 0.64539999 0.62599999 0.63980001]]]
